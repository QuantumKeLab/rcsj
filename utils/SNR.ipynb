# %%
import numpy as np
import matplotlib.pyplot as plt

def calculate_snr(signal, noise):
    signal_power = np.mean(signal**2)
    noise_power = np.var(noise)
    snr = 10 * np.log10(signal_power / noise_power)
    return snr

# Parameters
N = 1000
x = np.linspace(0, 1, N)
signal = 1.25 * x + 0.03
noise_std = 0.1
noise = np.random.normal(0, noise_std, N)
noisy_signal = signal + noise

# SNR Calculation
snr_value = calculate_snr(signal, noise)

# Plotting
plt.figure(figsize=(10, 6))
plt.plot(x, noisy_signal, label='Noisy Signal', alpha=0.7)
plt.plot(x, signal, label='Ideal Signal', linewidth=2)
plt.legend()
plt.xlabel('x')
plt.ylabel('y')
plt.title(f'SNR: {snr_value:.2f} dB')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

def calculate_snr(noisy_signal, noise_std):
    noise_power = noise_std**2
    signal_power = np.mean(noisy_signal**2) - noise_power
    snr = 10 * np.log10(signal_power / noise_power)
    return snr

# Parameters
N = 1000
x = np.linspace(0, 1, N)
signal = 1.25 * x + 0.03
noise_std = 0.1
noise = np.random.normal(0, noise_std, N)
noisy_signal = signal + noise

# SNR Calculation
snr_value = calculate_snr(noisy_signal, noise_std)

# Plotting
plt.figure(figsize=(10, 6))
plt.plot(x, noisy_signal, label='Noisy Signal', alpha=0.7)
plt.plot(x, signal, label='Ideal Signal', linewidth=2)
plt.legend()
plt.xlabel('x')
plt.ylabel('y')
plt.title(f'SNR: {snr_value:.2f} dB')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import linregress

def calculate_snr(noisy_signal, estimated_signal):
    noise = noisy_signal - estimated_signal
    signal_power = np.mean(estimated_signal**2)
    noise_power = np.mean(noise**2)
    snr = 10 * np.log10(signal_power / noise_power)
    return snr

# Parameters
N = 1000
x = np.linspace(0, 1, N)
signal = 1.25 * x + 0.03
noise_std = 0.1
noise = np.random.normal(0, noise_std, N)
noisy_signal = signal + noise

# Linear fit to estimate the signal
slope, intercept, _, _, _ = linregress(x, noisy_signal)
estimated_signal = slope * x + intercept

# SNR Calculation
snr_value = calculate_snr(noisy_signal, estimated_signal)

# Plotting
plt.figure(figsize=(10, 6))
plt.plot(x, noisy_signal, label='Noisy Signal', alpha=0.7)
plt.plot(x, signal, label='Ideal Signal', linewidth=2)
plt.plot(x, estimated_signal, label='Estimated Signal', linestyle='--')
plt.legend()
plt.xlabel('x')
plt.ylabel('y')
plt.title(f'SNR: {snr_value:.2f} dB')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import linregress

def calculate_snr(noisy_signal, estimated_signal):
    noise = noisy_signal - estimated_signal
    signal_power = np.mean(estimated_signal**2)
    noise_power = np.var(noise)
    snr = 10 * np.log10(signal_power / noise_power)
    return snr

# Parameters
N = 1000
x = np.linspace(0, 1, N)
signal = 1.25 * x + 0.03
noise_std = 0.1
noise = np.random.normal(0, noise_std, N)
noisy_signal = signal + noise

# Linear fit to estimate the signal
slope, intercept, _, _, _ = linregress(x, noisy_signal)
estimated_signal = slope * x + intercept

# SNR Calculation
snr_value = calculate_snr(noisy_signal, estimated_signal)

# Plotting
plt.figure(figsize=(10, 6))
plt.plot(x, noisy_signal, label='Noisy Signal', alpha=0.7)
plt.plot(x, signal, label='Ideal Signal', linewidth=2)
plt.plot(x, estimated_signal, label='Estimated Signal', linestyle='--')
plt.legend()
plt.xlabel('x')
plt.ylabel('y')
plt.title(f'SNR: {snr_value:.2f} dB')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import linregress

def calculate_snr(noisy_signal, estimated_signal):
    noise = noisy_signal - estimated_signal
    signal_power = np.mean(estimated_signal**2)
    noise_power = np.var(noise)
    snr = 10 * np.log10(signal_power / noise_power)
    return snr

# Parameters
N = 1000
x = np.linspace(0, 1, N)
signal = 1.25 * x + 0.03
noise_std = 0.01
noise = np.random.normal(0, noise_std, N)
noisy_signal = signal + noise

# Linear fit to estimate the signal
slope, intercept, r, p,  std_err = linregress(x, noisy_signal)
estimated_signal = slope * x + intercept
print(f'Slope: {slope:.4f}')
print(f'Intercept: {intercept:.4f}')
print(f'R-value: {r:.4f}')
print(f'P-value: {p:.4f}')
print(f'Std. Error: {std_err:.4f}')
# Calculate noise standard deviation from residuals
residuals = noisy_signal - estimated_signal
estimated_noise_std = np.std(residuals)

# SNR Calculation
snr_value = calculate_snr(noisy_signal, estimated_signal)

# Plotting
plt.figure(figsize=(10, 6))
plt.plot(x, noisy_signal, label='Noisy Signal', alpha=0.7)
plt.plot(x, signal, label='Ideal Signal', linewidth=2)
plt.plot(x, estimated_signal, label='Estimated Signal', linestyle='--')
plt.legend()
plt.xlabel('x')
plt.ylabel('y')
plt.title(f'SNR: {snr_value:.2f} dB')
plt.show()

print(f'Estimated noise standard deviation: {estimated_noise_std:.4f}')
# Out:
# Slope: 1.2506
# Intercept: 0.0297
# R-value: 0.9996
# P-value: 0.0000
# Std. Error: 0.0011
# Estimated noise standard deviation: 0.0097

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import linregress

def calculate_snr(noisy_signal, estimated_signal):
    noise = noisy_signal - estimated_signal
    signal_power = np.mean(estimated_signal**2)
    noise_power = np.var(noise)
    snr = 10 * np.log10(signal_power / noise_power)
    return snr

# Parameters
N = 1000
x = np.linspace(0, 1, N)
signal = 0 * x + 0.01  # Ideal signal y = 0 * x + 0.01
noise_std = 0.01
noise = np.random.normal(0, noise_std, N)
noisy_signal = signal + noise

# Linear fit to estimate the signal
slope, intercept, r, p, std_err = linregress(x, noisy_signal)
estimated_signal = slope * x + intercept
print(f'Slope: {slope:.4f}')
print(f'Intercept: {intercept:.4f}')
print(f'R-value: {r:.4f}')
print(f'P-value: {p:.4f}')
print(f'Std. Error: {std_err:.4f}')

# Calculate noise standard deviation from residuals
residuals = noisy_signal - estimated_signal
estimated_noise_std = np.std(residuals)

# SNR Calculation
snr_value = calculate_snr(noisy_signal, estimated_signal)

# Plotting
plt.figure(figsize=(10, 6))
plt.plot(x, noisy_signal, label='Noisy Signal', alpha=0.7)
plt.plot(x, signal, label='Ideal Signal', linewidth=2)
plt.plot(x, estimated_signal, label='Estimated Signal', linestyle='--')
plt.legend()
plt.xlabel('x')
plt.ylabel('y')
plt.title(f'SNR: {snr_value:.2f} dB')
plt.show()

print(f'Estimated noise standard deviation: {estimated_noise_std:.4f}')
# Out:
# Slope: -0.0003
# Intercept: 0.0095
# R-value: -0.0081
# P-value: 0.7988
# Std. Error: 0.0011
# Estimated noise standard deviation: 0.0103

# %%
import jax.numpy as jnp
x = currents_applied
y = dV_dI
params = jnp.polyfit(x, y, 0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 2
#       1 import jax.numpy as jnp
# ----> 2 x = currents_applied
#       3 y = dV_dI
#       4 params = jnp.polyfit(x, y, 0)
#
# NameError: name 'currents_applied' is not defined
